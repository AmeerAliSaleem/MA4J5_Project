# %% [markdown]
# <a href="https://colab.research.google.com/github/AmeerAliSaleem/MA4J5_Project/blob/main/Ameer_Ali_Saleem_MA4J5_binary_class_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import regex as re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
sns.set()

# %%
df = pd.read_csv("binary_class_balanced.csv")

# %%
df.head()
# Out:
#     overall   reviewTime                                         reviewText  \
# 0  Negative  11 12, 2013  I could not read the entire story. The book wa...
# 1  Positive   09 9, 2013  Greetings from Australia. A brilliant story. W...
# 2  Positive  01 25, 2014  My first book from this author and I really li...
# 3  Positive  02 24, 2016  Dark City is quite a dark novel, chilling and ...
# 4  Negative  03 16, 2015                                           Plodding
#
#                          summary
# 0                           nope
# 1                      Brilliant
# 2                      Beautiful
# 3  Dark thriller, worth reading.
# 4                      Two Stars

# %%
df['overall'].value_counts()
# Out:
# Negative    85690
# Positive    85690
# Name: overall, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171380 entries, 0 to 171379
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   overall     171380 non-null  object
#  1   reviewTime  171380 non-null  object
#  2   reviewText  171339 non-null  object
#  3   summary     171294 non-null  object
# dtypes: object(4)
# memory usage: 5.2+ MB

# %% [markdown]
# # Text Preprocessing

# %%
df["reviewText"] = df["reviewText"].astype(str)

# %%
stopwords = nltk.corpus.stopwords.words('english')
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
reviews_cleaned = []

for i in range(len(df["reviewText"])):
  reviews_raw = df["reviewText"].iloc[i]
  reviews_edit_1 = reviews_raw.lower()
  reviews_edit_2 = re.sub(r"[^a-zA-Z0-9\s\.]", "", reviews_edit_1) # Filter punctuation
  # reviews_edit_3 = re.sub(" \.|\. ", "", reviews_edit_2) # Get rid of fullstops that are outside of words
  reviews_cleaned.append(reviews_edit_2.strip()) # remove unnecessary whitespace and append to list of cleaned reviews

# %%
# remove stopwords from the cleaned list
filtered_reviews = [
    ' '.join(word for word in sentence.split() if word.lower() not in stopwords)
    for sentence in reviews_cleaned
]

# %%
# compare first record vs record with stopwords removed
print(reviews_cleaned[0])
print(filtered_reviews[0])
# Out:
# i could not read the entire story. the book was a complete waste of my time glad i got it as a freebie.
# could read entire story. book complete waste time glad got freebie.

# %%
# observe first five filtered reviews + scores
for i in range(5):
  print(filtered_reviews[i])
  print(df["overall"][i])
# Out:
# could read entire story. book complete waste time glad got freebie.
# Negative
# greetings australia. brilliant story. knew could maintain interest tension conversation waitress old man. stephen king better job writing interesting prose seemingly mundane. highly recommended.
# Positive
# first book author really like her. follow writings. like dynamics work. characters easy understand follow. must read .
# Positive
# dark city quite dark novel chilling intricate kind read through. even havent read previous novels series case stand alone piece. starts somewhat familiar scenario private detective drinks smokes capable outwitting local police enforcement. yet typical really. even protagonist seems familiar rest characters quite different youd expect theyre interesting follow. plot interesting emotional twists turns bring feeling uneasiness alertness one loves getting good thriller. london atmosphere quite attractive well. enjoyed authors sense humor darkish strong. would recommend novel specially readers like dark plots noir settings. im looking forward next book series.
# Positive
# plodding
# Negative

# %% [markdown]
# ## Train-test split

# %%
labels = list(df["overall"])

# Shuffle the data.

filtered_reviews, labels = zip(*random.sample(list(zip(filtered_reviews,labels)), len(filtered_reviews)))
filtered_reviews = list(filtered_reviews)
labels = list(labels)

# Train-test split (66:33)

trainsize = int(len(filtered_reviews)*0.66)

train_reviews, train_labels = filtered_reviews[:trainsize], labels[:trainsize]
test_reviews, test_labels = filtered_reviews[trainsize:], labels[trainsize:]

# %%
# Check distribution reviews in the training set

print("TRAINING SET")
print("Number of reviews to use for training is: {}.".format(len(train_labels)))
print("Number of positive reviews is: {} (or {:.1f}%).".format(sum(np.array(train_labels)=='Positive'),100*sum(np.array(train_labels)=='Positive')/len(train_labels)))
print("Number of 3-negative reviews is: {} (or {:.1f}%).".format(sum(np.array(train_labels)=='Negative'),100*sum(np.array(train_labels)=='Negative')/len(train_labels)))
# Out:
# TRAINING SET
# Number of reviews to use for training is: 113110.
# Number of positive reviews is: 56512 (or 50.0%).
# Number of 3-negative reviews is: 56598 (or 50.0%).

# %% [markdown]
# ## Tokenisation

# %% [markdown]
# The word tokenizer provided by the Keras package will be able to deal with full stops for us, e.g. "missing." and "missing" will be treated as the same token.
#
# Now for the tokenisation. In particular, we must conduct this separately on the training and test sets. The reason for this is due to so-called "data leakage": we do not want to introduce any elements of the testing data to the network before or during training. These two sets should be kept as separate as possible.
#
# In the following:
# * `vocab_size' corresponds to the n most common words in the dataset to be vectorised.
# * `max_length' corresponds to the maxmimum length of the word embedding vectors to use as input for our neural network.

# %%
# max size of our vectorised corpus
vocab_size = 2500

# maximum allowed length for each vectorised sentence into our neural network
max_length = 50

# Tokenization
# OOV token deals with words that our tokenizer has not seen before (e.g. in the test set)
tokenizer = Tokenizer(num_words = vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(train_reviews)
word_index = tokenizer.word_index

train_sequences = tokenizer.texts_to_sequences(train_reviews)
test_sequences = tokenizer.texts_to_sequences(test_reviews)

# padding sequences to standardise the input size of each row of data for our NN
train_padded = pad_sequences(train_sequences, maxlen=max_length, padding='post', truncating='post')
test_padded = pad_sequences(test_sequences, maxlen=max_length, padding='post', truncating='post')

# %%
print(len(train_padded))
# Out:
# 113110

# %%
type(train_labels[0])
# Out:
# str

# %%
# convert sentiment classes to numbers

sentiment_to_number = {'Positive':1, 'Negative':0}

train_labels = [sentiment_to_number.get(item, item) for item in train_labels]
test_labels = [sentiment_to_number.get(item, item) for item in test_labels]

# %%
print(test_labels[:10])
# Out:
# [0, 1, 0, 0, 1, 0, 1, 0, 0, 1]

# %% [markdown]
# # Model Building and Evaluation: binary-class setup

# %% [markdown]
# We now experiment with a variety of neural network architectures, with the aim of maximising the accuracy of our model on the *testing set*.

# %%
# function to plot and analyse the learning of each neural network
def learning_curve(history):
    plt.figure(figsize=(10,12))

    # Loss subplot.
    plt.subplot(2,1,1)
    plt.plot(history.history['loss'], label='Training loss')
    plt.plot(history.history['val_loss'], label='Testing loss')
    plt.title('Learning Curve')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Accuracy subplot.
    plt.subplot(2,1,2)
    plt.plot(history.history['accuracy'], label='Training accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation accuracy')
    plt.title('Learning Curve')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.show()

# %% [markdown]
# ### Experimenting with model architectures
# ---

# %%
# model hyperparameters
embedding_dim = 16
num_epochs = 30
batch_size = 1000

# Average pooling
model1 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(2, activation='softmax')
])
model1.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

model1.summary()

history1 = model1.fit(train_padded, tf.one_hot(train_labels,2), batch_size=batch_size, epochs=num_epochs, validation_data=(test_padded, tf.one_hot(test_labels,2)), verbose=2)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 50, 16)            40000
#
#  global_average_pooling1d_2  (None, 16)                0
#   (GlobalAveragePooling1D)
#
#  dense_2 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 40034 (156.38 KB)
# Trainable params: 40034 (156.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 114/114 - 2s - loss: 0.6739 - accuracy: 0.6818 - val_loss: 0.6445 - val_accuracy: 0.7549 - 2s/epoch - 19ms/step
# Epoch 2/30
# 114/114 - 1s - loss: 0.6037 - accuracy: 0.8013 - val_loss: 0.5579 - val_accuracy: 0.8354 - 1s/epoch - 10ms/step
# Epoch 3/30
# 114/114 - 1s - loss: 0.5162 - accuracy: 0.8483 - val_loss: 0.4762 - val_accuracy: 0.8548 - 906ms/epoch - 8ms/step
# Epoch 4/30
# 114/114 - 1s - loss: 0.4452 - accuracy: 0.8642 - val_loss: 0.4182 - val_accuracy: 0.8667 - 911ms/epoch - 8ms/step
# Epoch 5/30
# 114/114 - 1s - loss: 0.3966 - accuracy: 0.8733 - val_loss: 0.3800 - val_accuracy: 0.8743 - 1s/epoch - 9ms/step
# Epoch 6/30
# 114/114 - 1s - loss: 0.3640 - accuracy: 0.8791 - val_loss: 0.3546 - val_accuracy: 0.8774 - 1s/epoch - 12ms/step
# Epoch 7/30
# 114/114 - 1s - loss: 0.3415 - accuracy: 0.8833 - val_loss: 0.3370 - val_accuracy: 0.8801 - 1s/epoch - 12ms/step
# Epoch 8/30
# 114/114 - 1s - loss: 0.3254 - accuracy: 0.8858 - val_loss: 0.3244 - val_accuracy: 0.8827 - 1s/epoch - 11ms/step
# Epoch 9/30
# 114/114 - 1s - loss: 0.3132 - accuracy: 0.8884 - val_loss: 0.3149 - val_accuracy: 0.8841 - 911ms/epoch - 8ms/step
# Epoch 10/30
# 114/114 - 1s - loss: 0.3039 - accuracy: 0.8901 - val_loss: 0.3079 - val_accuracy: 0.8852 - 906ms/epoch - 8ms/step
# Epoch 11/30
# 114/114 - 1s - loss: 0.2965 - accuracy: 0.8922 - val_loss: 0.3026 - val_accuracy: 0.8867 - 897ms/epoch - 8ms/step
# Epoch 12/30
# 114/114 - 1s - loss: 0.2906 - accuracy: 0.8935 - val_loss: 0.2983 - val_accuracy: 0.8872 - 900ms/epoch - 8ms/step
# Epoch 13/30
# 114/114 - 1s - loss: 0.2858 - accuracy: 0.8946 - val_loss: 0.2951 - val_accuracy: 0.8876 - 1s/epoch - 9ms/step
# Epoch 14/30
# 114/114 - 1s - loss: 0.2819 - accuracy: 0.8956 - val_loss: 0.2926 - val_accuracy: 0.8887 - 904ms/epoch - 8ms/step
# Epoch 15/30
# 114/114 - 1s - loss: 0.2787 - accuracy: 0.8966 - val_loss: 0.2908 - val_accuracy: 0.8889 - 1s/epoch - 9ms/step
# Epoch 16/30
# 114/114 - 1s - loss: 0.2761 - accuracy: 0.8971 - val_loss: 0.2892 - val_accuracy: 0.8895 - 1s/epoch - 9ms/step
# Epoch 17/30
# 114/114 - 1s - loss: 0.2739 - accuracy: 0.8977 - val_loss: 0.2881 - val_accuracy: 0.8891 - 891ms/epoch - 8ms/step
# Epoch 18/30
# 114/114 - 1s - loss: 0.2720 - accuracy: 0.8978 - val_loss: 0.2873 - val_accuracy: 0.8901 - 1s/epoch - 9ms/step
# Epoch 19/30
# 114/114 - 1s - loss: 0.2704 - accuracy: 0.8987 - val_loss: 0.2868 - val_accuracy: 0.8895 - 1s/epoch - 12ms/step
# Epoch 20/30
# 114/114 - 2s - loss: 0.2691 - accuracy: 0.8989 - val_loss: 0.2863 - val_accuracy: 0.8905 - 2s/epoch - 13ms/step
# Epoch 21/30
# 114/114 - 1s - loss: 0.2680 - accuracy: 0.8996 - val_loss: 0.2862 - val_accuracy: 0.8908 - 1s/epoch - 11ms/step
# Epoch 22/30
# 114/114 - 1s - loss: 0.2671 - accuracy: 0.8995 - val_loss: 0.2859 - val_accuracy: 0.8909 - 1s/epoch - 9ms/step
# Epoch 23/30
# 114/114 - 1s - loss: 0.2662 - accuracy: 0.8999 - val_loss: 0.2859 - val_accuracy: 0.8909 - 905ms/epoch - 8ms/step
# Epoch 24/30
# 114/114 - 1s - loss: 0.2655 - accuracy: 0.9004 - val_loss: 0.2857 - val_accuracy: 0.8910 - 1s/epoch - 9ms/step
# Epoch 25/30
# 114/114 - 1s - loss: 0.2649 - accuracy: 0.9005 - val_loss: 0.2857 - val_accuracy: 0.8910 - 882ms/epoch - 8ms/step
# Epoch 26/30
# 114/114 - 1s - loss: 0.2644 - accuracy: 0.9011 - val_loss: 0.2859 - val_accuracy: 0.8907 - 884ms/epoch - 8ms/step
# Epoch 27/30
# 114/114 - 1s - loss: 0.2640 - accuracy: 0.9009 - val_loss: 0.2859 - val_accuracy: 0.8911 - 1s/epoch - 9ms/step
# Epoch 28/30
# 114/114 - 1s - loss: 0.2636 - accuracy: 0.9007 - val_loss: 0.2862 - val_accuracy: 0.8908 - 940ms/epoch - 8ms/step
# Epoch 29/30
# 114/114 - 1s - loss: 0.2632 - accuracy: 0.9009 - val_loss: 0.2863 - val_accuracy: 0.8908 - 906ms/epoch - 8ms/step
# Epoch 30/30
# 114/114 - 1s - loss: 0.2628 - accuracy: 0.9010 - val_loss: 0.2867 - val_accuracy: 0.8909 - 902ms/epoch - 8ms/step

# %%
learning_curve(history1)

# %%
# model hyperparameters
embedding_dim = 16
num_epochs = 15
batch_size = 1000

# LSTM setup
model2 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8)),
    tf.keras.layers.Dense(8, activation='tanh'),
    tf.keras.layers.Dense(2, activation='softmax')
])
model2.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

model2.summary()

history2 = model2.fit(train_padded, tf.one_hot(train_labels,2), batch_size=batch_size, epochs=num_epochs, validation_data=(test_padded, tf.one_hot(test_labels,2)), verbose=2)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 50, 16)            40000
#
#  bidirectional_1 (Bidirecti  (None, 16)                1600
#  onal)
#
#  dense_8 (Dense)             (None, 8)                 136
#
#  dense_9 (Dense)             (None, 2)                 18
#
# =================================================================
# Total params: 41754 (163.10 KB)
# Trainable params: 41754 (163.10 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/15
# 114/114 - 17s - loss: 0.5116 - accuracy: 0.7751 - val_loss: 0.3092 - val_accuracy: 0.8823 - 17s/epoch - 148ms/step
# Epoch 2/15
# 114/114 - 11s - loss: 0.2744 - accuracy: 0.8922 - val_loss: 0.2713 - val_accuracy: 0.8895 - 11s/epoch - 97ms/step
# Epoch 3/15
# 114/114 - 12s - loss: 0.2542 - accuracy: 0.8989 - val_loss: 0.2649 - val_accuracy: 0.8924 - 12s/epoch - 109ms/step
# Epoch 4/15
# 114/114 - 12s - loss: 0.2469 - accuracy: 0.9018 - val_loss: 0.2630 - val_accuracy: 0.8937 - 12s/epoch - 109ms/step
# Epoch 5/15
# 114/114 - 12s - loss: 0.2423 - accuracy: 0.9040 - val_loss: 0.2624 - val_accuracy: 0.8927 - 12s/epoch - 102ms/step
# Epoch 6/15
# 114/114 - 12s - loss: 0.2386 - accuracy: 0.9048 - val_loss: 0.2622 - val_accuracy: 0.8936 - 12s/epoch - 102ms/step
# Epoch 7/15
# 114/114 - 12s - loss: 0.2345 - accuracy: 0.9066 - val_loss: 0.2592 - val_accuracy: 0.8950 - 12s/epoch - 102ms/step
# Epoch 8/15
# 114/114 - 10s - loss: 0.2307 - accuracy: 0.9085 - val_loss: 0.2590 - val_accuracy: 0.8949 - 10s/epoch - 92ms/step
# Epoch 9/15
# 114/114 - 11s - loss: 0.2271 - accuracy: 0.9101 - val_loss: 0.2616 - val_accuracy: 0.8931 - 11s/epoch - 98ms/step
# Epoch 10/15
# 114/114 - 12s - loss: 0.2245 - accuracy: 0.9104 - val_loss: 0.2604 - val_accuracy: 0.8941 - 12s/epoch - 102ms/step
# Epoch 11/15
# 114/114 - 12s - loss: 0.2210 - accuracy: 0.9126 - val_loss: 0.2599 - val_accuracy: 0.8933 - 12s/epoch - 102ms/step
# Epoch 12/15
# 114/114 - 12s - loss: 0.2183 - accuracy: 0.9140 - val_loss: 0.2610 - val_accuracy: 0.8935 - 12s/epoch - 110ms/step
# Epoch 13/15
# 114/114 - 12s - loss: 0.2159 - accuracy: 0.9154 - val_loss: 0.2640 - val_accuracy: 0.8919 - 12s/epoch - 107ms/step
# Epoch 14/15
# 114/114 - 12s - loss: 0.2147 - accuracy: 0.9152 - val_loss: 0.2633 - val_accuracy: 0.8931 - 12s/epoch - 101ms/step
# Epoch 15/15
# 114/114 - 11s - loss: 0.2111 - accuracy: 0.9173 - val_loss: 0.2656 - val_accuracy: 0.8916 - 11s/epoch - 97ms/step

# %%
learning_curve(history2)

# %%
# model hyperparameters
embedding_dim = 8
num_epochs = 15
batch_size = 1000

# flatten layer
model3 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(8, activation='sigmoid'),
    tf.keras.layers.Dense(2, activation='softmax')
])
model3.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

model3.summary()

history3 = model3.fit(train_padded, tf.one_hot(train_labels,2), batch_size=batch_size, epochs=num_epochs, validation_data=(test_padded, tf.one_hot(test_labels,2)), verbose=2)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 50, 8)             20000
#
#  flatten_1 (Flatten)         (None, 400)               0
#
#  dense_10 (Dense)            (None, 8)                 3208
#
#  dense_11 (Dense)            (None, 2)                 18
#
# =================================================================
# Total params: 23226 (90.73 KB)
# Trainable params: 23226 (90.73 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/15
# 114/114 - 2s - loss: 0.6357 - accuracy: 0.6973 - val_loss: 0.4888 - val_accuracy: 0.8510 - 2s/epoch - 16ms/step
# Epoch 2/15
# 114/114 - 1s - loss: 0.3734 - accuracy: 0.8729 - val_loss: 0.3126 - val_accuracy: 0.8809 - 871ms/epoch - 8ms/step
# Epoch 3/15
# 114/114 - 1s - loss: 0.2864 - accuracy: 0.8910 - val_loss: 0.2818 - val_accuracy: 0.8886 - 1s/epoch - 9ms/step
# Epoch 4/15
# 114/114 - 1s - loss: 0.2646 - accuracy: 0.8974 - val_loss: 0.2746 - val_accuracy: 0.8907 - 863ms/epoch - 8ms/step
# Epoch 5/15
# 114/114 - 1s - loss: 0.2561 - accuracy: 0.9002 - val_loss: 0.2717 - val_accuracy: 0.8913 - 1s/epoch - 9ms/step
# Epoch 6/15
# 114/114 - 1s - loss: 0.2516 - accuracy: 0.9023 - val_loss: 0.2709 - val_accuracy: 0.8921 - 1s/epoch - 9ms/step
# Epoch 7/15
# 114/114 - 1s - loss: 0.2483 - accuracy: 0.9034 - val_loss: 0.2705 - val_accuracy: 0.8923 - 876ms/epoch - 8ms/step
# Epoch 8/15
# 114/114 - 1s - loss: 0.2458 - accuracy: 0.9044 - val_loss: 0.2712 - val_accuracy: 0.8922 - 1s/epoch - 10ms/step
# Epoch 9/15
# 114/114 - 1s - loss: 0.2433 - accuracy: 0.9058 - val_loss: 0.2705 - val_accuracy: 0.8931 - 1s/epoch - 12ms/step
# Epoch 10/15
# 114/114 - 1s - loss: 0.2409 - accuracy: 0.9072 - val_loss: 0.2714 - val_accuracy: 0.8924 - 1s/epoch - 12ms/step
# Epoch 11/15
# 114/114 - 1s - loss: 0.2383 - accuracy: 0.9085 - val_loss: 0.2712 - val_accuracy: 0.8930 - 877ms/epoch - 8ms/step
# Epoch 12/15
# 114/114 - 1s - loss: 0.2358 - accuracy: 0.9097 - val_loss: 0.2713 - val_accuracy: 0.8930 - 862ms/epoch - 8ms/step
# Epoch 13/15
# 114/114 - 1s - loss: 0.2328 - accuracy: 0.9109 - val_loss: 0.2717 - val_accuracy: 0.8927 - 990ms/epoch - 9ms/step
# Epoch 14/15
# 114/114 - 1s - loss: 0.2298 - accuracy: 0.9125 - val_loss: 0.2724 - val_accuracy: 0.8926 - 990ms/epoch - 9ms/step
# Epoch 15/15
# 114/114 - 1s - loss: 0.2264 - accuracy: 0.9139 - val_loss: 0.2741 - val_accuracy: 0.8919 - 1s/epoch - 9ms/step

# %%
learning_curve(history3)

# %%
# model hyperparameters
embedding_dim = 16
num_epochs = 15
batch_size = 1000

# convolution
model4 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(2, activation='softmax')
])
model4.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

model4.summary()

history4 = model4.fit(train_padded, tf.one_hot(train_labels,2), batch_size=batch_size, epochs=num_epochs, validation_data=(test_padded, tf.one_hot(test_labels,2)), verbose=2)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 50, 16)            40000
#
#  conv1d (Conv1D)             (None, 46, 128)           10368
#
#  global_max_pooling1d (Glob  (None, 128)               0
#  alMaxPooling1D)
#
#  dense_7 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 50626 (197.76 KB)
# Trainable params: 50626 (197.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/15
# 114/114 - 16s - loss: 0.4663 - accuracy: 0.8054 - val_loss: 0.3018 - val_accuracy: 0.8740 - 16s/epoch - 136ms/step
# Epoch 2/15
# 114/114 - 15s - loss: 0.2811 - accuracy: 0.8847 - val_loss: 0.2846 - val_accuracy: 0.8819 - 15s/epoch - 127ms/step
# Epoch 3/15
# 114/114 - 14s - loss: 0.2640 - accuracy: 0.8929 - val_loss: 0.2792 - val_accuracy: 0.8863 - 14s/epoch - 119ms/step
# Epoch 4/15
# 114/114 - 15s - loss: 0.2532 - accuracy: 0.8978 - val_loss: 0.2755 - val_accuracy: 0.8882 - 15s/epoch - 128ms/step
# Epoch 5/15
# 114/114 - 15s - loss: 0.2441 - accuracy: 0.9019 - val_loss: 0.2738 - val_accuracy: 0.8887 - 15s/epoch - 127ms/step
# Epoch 6/15
# 114/114 - 14s - loss: 0.2366 - accuracy: 0.9059 - val_loss: 0.2713 - val_accuracy: 0.8899 - 14s/epoch - 127ms/step
# Epoch 7/15
# 114/114 - 14s - loss: 0.2289 - accuracy: 0.9099 - val_loss: 0.2710 - val_accuracy: 0.8904 - 14s/epoch - 127ms/step
# Epoch 8/15
# 114/114 - 14s - loss: 0.2214 - accuracy: 0.9136 - val_loss: 0.2705 - val_accuracy: 0.8905 - 14s/epoch - 122ms/step
# Epoch 9/15
# 114/114 - 14s - loss: 0.2142 - accuracy: 0.9166 - val_loss: 0.2708 - val_accuracy: 0.8906 - 14s/epoch - 120ms/step
# Epoch 10/15
# 114/114 - 13s - loss: 0.2061 - accuracy: 0.9205 - val_loss: 0.2718 - val_accuracy: 0.8902 - 13s/epoch - 118ms/step
# Epoch 11/15
# 114/114 - 13s - loss: 0.1985 - accuracy: 0.9246 - val_loss: 0.2745 - val_accuracy: 0.8909 - 13s/epoch - 118ms/step
# Epoch 12/15
# 114/114 - 14s - loss: 0.1909 - accuracy: 0.9281 - val_loss: 0.2773 - val_accuracy: 0.8902 - 14s/epoch - 120ms/step
# Epoch 13/15
# 114/114 - 13s - loss: 0.1834 - accuracy: 0.9316 - val_loss: 0.2798 - val_accuracy: 0.8896 - 13s/epoch - 117ms/step
# Epoch 14/15
# 114/114 - 13s - loss: 0.1758 - accuracy: 0.9347 - val_loss: 0.2839 - val_accuracy: 0.8894 - 13s/epoch - 113ms/step
# Epoch 15/15
# 114/114 - 14s - loss: 0.1684 - accuracy: 0.9384 - val_loss: 0.2876 - val_accuracy: 0.8888 - 14s/epoch - 125ms/step

# %%
learning_curve(history4)

# %%
# model hyperparameters
embedding_dim = 16
num_epochs = 15
batch_size = 1000

# more complicated LSTM setup
model5 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16)),
    tf.keras.layers.Dense(8, activation='tanh'),
    tf.keras.layers.Dense(2, activation='softmax')
])
model5.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

model5.summary()

history5 = model5.fit(train_padded, tf.one_hot(train_labels,2), batch_size=batch_size, epochs=num_epochs, validation_data=(test_padded, tf.one_hot(test_labels,2)), verbose=2)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 50, 16)            40000
#
#  bidirectional_2 (Bidirecti  (None, 50, 64)            12544
#  onal)
#
#  bidirectional_3 (Bidirecti  (None, 32)                10368
#  onal)
#
#  dense_12 (Dense)            (None, 8)                 264
#
#  dense_13 (Dense)            (None, 2)                 18
#
# =================================================================
# Total params: 63194 (246.85 KB)
# Trainable params: 63194 (246.85 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/15
# 114/114 - 87s - loss: 0.3973 - accuracy: 0.8139 - val_loss: 0.2746 - val_accuracy: 0.8890 - 87s/epoch - 760ms/step
# Epoch 2/15
# 114/114 - 77s - loss: 0.2597 - accuracy: 0.8954 - val_loss: 0.2644 - val_accuracy: 0.8915 - 77s/epoch - 677ms/step
# Epoch 3/15
# 114/114 - 77s - loss: 0.2506 - accuracy: 0.8994 - val_loss: 0.2645 - val_accuracy: 0.8914 - 77s/epoch - 676ms/step
# Epoch 4/15
# 114/114 - 76s - loss: 0.2448 - accuracy: 0.9018 - val_loss: 0.2689 - val_accuracy: 0.8895 - 76s/epoch - 663ms/step
# Epoch 5/15
# 114/114 - 76s - loss: 0.2443 - accuracy: 0.9014 - val_loss: 0.2611 - val_accuracy: 0.8934 - 76s/epoch - 664ms/step
# Epoch 6/15
# 114/114 - 76s - loss: 0.2361 - accuracy: 0.9064 - val_loss: 0.2628 - val_accuracy: 0.8928 - 76s/epoch - 664ms/step
# Epoch 7/15
# 114/114 - 77s - loss: 0.2332 - accuracy: 0.9071 - val_loss: 0.2610 - val_accuracy: 0.8935 - 77s/epoch - 674ms/step
# Epoch 8/15
# 114/114 - 76s - loss: 0.2300 - accuracy: 0.9092 - val_loss: 0.2608 - val_accuracy: 0.8936 - 76s/epoch - 669ms/step
# Epoch 9/15
# 114/114 - 77s - loss: 0.2279 - accuracy: 0.9085 - val_loss: 0.2613 - val_accuracy: 0.8922 - 77s/epoch - 674ms/step
# Epoch 10/15
# 114/114 - 77s - loss: 0.2252 - accuracy: 0.9109 - val_loss: 0.2612 - val_accuracy: 0.8924 - 77s/epoch - 680ms/step
# Epoch 11/15
# 114/114 - 76s - loss: 0.2226 - accuracy: 0.9109 - val_loss: 0.2724 - val_accuracy: 0.8894 - 76s/epoch - 666ms/step
# Epoch 12/15
# 114/114 - 77s - loss: 0.2202 - accuracy: 0.9122 - val_loss: 0.2660 - val_accuracy: 0.8915 - 77s/epoch - 672ms/step
# Epoch 13/15
# 114/114 - 76s - loss: 0.2179 - accuracy: 0.9135 - val_loss: 0.2675 - val_accuracy: 0.8918 - 76s/epoch - 669ms/step
# Epoch 14/15
# 114/114 - 76s - loss: 0.2142 - accuracy: 0.9144 - val_loss: 0.2696 - val_accuracy: 0.8894 - 76s/epoch - 669ms/step
# Epoch 15/15
# 114/114 - 76s - loss: 0.2117 - accuracy: 0.9158 - val_loss: 0.2693 - val_accuracy: 0.8914 - 76s/epoch - 670ms/step

# %%
learning_curve(history5)

# %%
# Plot all five learning curves on the same axes.
plt.figure(figsize=(14,10))

# plt.axhline(0.5, label='Baseline', color='black')
plt.plot(history1.history['accuracy'], label='Pooling (Train)', color='orange', linestyle='dashed')
plt.plot(history1.history['val_accuracy'], label='Pooling (Test)', color='orange')
plt.plot(history2.history['accuracy'], label='LSTM (Train)', color='red', linestyle='dashed')
plt.plot(history2.history['val_accuracy'], label='LSTM (Test)', color='red')
plt.plot(history3.history['accuracy'], label='Flatten (Train)', color='green', linestyle='dashed')
plt.plot(history3.history['val_accuracy'], label='Flatten (Test)', color='green')
plt.plot(history4.history['accuracy'], label='Convolution (Train)', color='blue', linestyle='dashed')
plt.plot(history4.history['val_accuracy'], label='Convolution (Test)', color='blue')
plt.plot(history5.history['accuracy'], label='Stacked LSTM (Train)', color='purple', linestyle='dashed')
plt.plot(history5.history['val_accuracy'], label='Stacked LSTM (Test)', color='purple')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xlim(0,14)
# plt.ylim((0.5,0.8))
plt.title('Learning Curves for NLP Binary Classification')

plt.show()
