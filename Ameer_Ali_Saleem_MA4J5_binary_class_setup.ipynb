# %% [markdown]
# <a href="https://colab.research.google.com/github/AmeerAliSaleem/MA4J5_Project/blob/main/Ameer_Ali_Saleem_MA4J5_binary_class_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import regex as re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
sns.set()

# %%
df = pd.read_csv("binary_class_balanced.csv")

# %%
df.head()
# Out:
#     overall   reviewTime                                         reviewText  \
# 0  Negative  11 12, 2013  I could not read the entire story. The book wa...
# 1  Positive   09 9, 2013  Greetings from Australia. A brilliant story. W...
# 2  Positive  01 25, 2014  My first book from this author and I really li...
# 3  Positive  02 24, 2016  Dark City is quite a dark novel, chilling and ...
# 4  Negative  03 16, 2015                                           Plodding
#
#                          summary
# 0                           nope
# 1                      Brilliant
# 2                      Beautiful
# 3  Dark thriller, worth reading.
# 4                      Two Stars

# %%
df['overall'].value_counts()
# Out:
# Negative    85690
# Positive    85690
# Name: overall, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171380 entries, 0 to 171379
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   overall     171380 non-null  object
#  1   reviewTime  171380 non-null  object
#  2   reviewText  171339 non-null  object
#  3   summary     171294 non-null  object
# dtypes: object(4)
# memory usage: 5.2+ MB

# %% [markdown]
# # Text Preprocessing

# %%
df["reviewText"] = df["reviewText"].astype(str)

# %%
stopwords = nltk.corpus.stopwords.words('english')
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# custom stopwords
stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've",
             "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself',
             'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them',
             'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll",
             'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has',
             'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or',
             'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against',
             'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from',
             'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then',
             'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each',
             'few', 'more', 'most', 'other', 'some', 'such']

# %%
reviews_cleaned = []

for i in range(len(df["reviewText"])):
  reviews_raw = df["reviewText"].iloc[i]
  reviews_edit_1 = reviews_raw.lower()
  reviews_edit_2 = re.sub(r"[^a-zA-Z0-9\s\.]", "", reviews_edit_1) # Filter punctuation
  # reviews_edit_3 = re.sub(" \.|\. ", "", reviews_edit_2) # Get rid of fullstops that are outside of words
  reviews_cleaned.append(reviews_edit_2.strip()) # remove unnecessary whitespace and append to list of cleaned reviews

# %%
# remove stopwords from the cleaned list
filtered_reviews = [
    ' '.join(word for word in sentence.split() if word.lower() not in stopwords)
    for sentence in reviews_cleaned
]

# %%
# compare first record vs record with stopwords removed
print(reviews_cleaned[0])
print(filtered_reviews[0])
# Out:
# i could not read the entire story. the book was a complete waste of my time glad i got it as a freebie.
# could not read entire story. book complete waste time glad got freebie.

# %%
# observe first five filtered reviews + scores
for i in range(5):
  print(filtered_reviews[i])
  print(df["overall"][i])
# Out:
# could not read entire story. book complete waste time glad got freebie.
# Negative
# greetings australia. brilliant story. knew could maintain interest tension conversation waitress old man. only stephen king can better job writing interesting prose seemingly mundane. highly recommended.
# Positive
# first book author really like her. will follow writings. like dynamics work. characters very easy understand follow. must read .
# Positive
# dark city quite dark novel chilling intricate kind just read through. even havent read previous novels series case stand alone piece. starts somewhat familiar scenario private detective drinks smokes capable outwitting local police enforcement. yet not typical not really. even protagonist seems familiar rest characters quite different youd expect theyre interesting follow. plot very interesting emotional twists turns will bring feeling uneasiness alertness one loves getting good thriller. london atmosphere quite attractive well. enjoyed authors sense humor darkish strong. would recommend novel specially readers like dark plots noir settings. im looking forward next book series.
# Positive
# plodding
# Negative

# %% [markdown]
# ## Train-test split

# %%
labels = list(df["overall"])

# Shuffle the data.

filtered_reviews, labels = zip(*random.sample(list(zip(filtered_reviews,labels)), len(filtered_reviews)))
filtered_reviews = list(filtered_reviews)
labels = list(labels)

# Train-test split (66:33)

trainsize = int(len(filtered_reviews)*0.66)

train_reviews, train_labels = filtered_reviews[:trainsize], labels[:trainsize]
test_reviews, test_labels = filtered_reviews[trainsize:], labels[trainsize:]

# %%
# Check distribution reviews in the training set

print("TRAINING SET")
print("Number of reviews to use for training is: {}.".format(len(train_labels)))
print("Number of positive reviews is: {} (or {:.1f}%).".format(sum(np.array(train_labels)=='Positive'),100*sum(np.array(train_labels)=='Positive')/len(train_labels)))
print("Number of 3-negative reviews is: {} (or {:.1f}%).".format(sum(np.array(train_labels)=='Negative'),100*sum(np.array(train_labels)=='Negative')/len(train_labels)))
# Out:
# TRAINING SET
# Number of reviews to use for training is: 113110.
# Number of positive reviews is: 56537 (or 50.0%).
# Number of 3-negative reviews is: 56573 (or 50.0%).

# %% [markdown]
# ## Tokenisation

# %% [markdown]
# The word tokenizer provided by the Keras package will be able to deal with full stops for us, e.g. "missing." and "missing" will be treated as the same token.
#
# Now for the tokenisation. In particular, we must conduct this separately on the training and test sets. The reason for this is due to so-called "data leakage": we do not want to introduce any elements of the testing data to the network before or during training. These two sets should be kept as separate as possible.
#
# In the following:
# * `vocab_size' corresponds to the n most common words in the dataset to be vectorised.
# * `max_length' corresponds to the maxmimum length of the word embedding vectors to use as input for our neural network.

# %%
# max size of our vectorised corpus
vocab_size = 2500

# maximum allowed length for each vectorised sentence into our neural network
max_length = 50

# Tokenization
# OOV token deals with words that our tokenizer has not seen before (e.g. in the test set)
tokenizer = Tokenizer(num_words = vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(train_reviews)
word_index = tokenizer.word_index

train_sequences = tokenizer.texts_to_sequences(train_reviews)
test_sequences = tokenizer.texts_to_sequences(test_reviews)

# padding sequences to standardise the input size of each row of data for our NN
train_padded = pad_sequences(train_sequences, maxlen=max_length, padding='post', truncating='post')
test_padded = pad_sequences(test_sequences, maxlen=max_length, padding='post', truncating='post')

# %%
print(len(train_padded))
# Out:
# 113110

# %%
type(train_labels[0])
# Out:
# str

# %%
# convert sentiment classes to numbers

sentiment_to_number = {'Positive':1, 'Negative':0}

train_labels = [sentiment_to_number.get(item, item) for item in train_labels]
test_labels = [sentiment_to_number.get(item, item) for item in test_labels]

# %%
print(test_labels[:10])
# Out:
# [0, 1, 1, 0, 1, 0, 0, 0, 0, 0]

# %% [markdown]
# # Model Building and Evaluation: binary-class setup

# %% [markdown]
# We now experiment with a variety of neural network architectures, with the aim of maximising the accuracy of our model on the *testing set*.

# %%
# function to plot and analyse the learning of each neural network
def learning_curve(history):
    plt.figure(figsize=(10,12))

    # Loss subplot.
    plt.subplot(2,1,1)
    plt.plot(history.history['loss'], label='Training loss')
    plt.plot(history.history['val_loss'], label='Testing loss')
    plt.title('Learning Curve')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Accuracy subplot.
    plt.subplot(2,1,2)
    plt.plot(history.history['accuracy'], label='Training accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation accuracy')
    plt.title('Learning Curve')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.show()

# %% [markdown]
# ### Experimenting with model architectures
# ---

# %%
# model hyperparameters
embedding_dim = 16
num_epochs = 30
batch_size = 1000

# Average pooling
model1 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(2, activation='softmax')
])
model1.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

model1.summary()

history1 = model1.fit(train_padded, tf.one_hot(train_labels,2), batch_size=batch_size, epochs=num_epochs, validation_data=(test_padded, tf.one_hot(test_labels,2)), verbose=2)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 16)            40000
#
#  global_average_pooling1d (  (None, 16)                0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 2)                 34
#
# =================================================================
# Total params: 40034 (156.38 KB)
# Trainable params: 40034 (156.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 114/114 - 2s - loss: 0.6660 - accuracy: 0.6734 - val_loss: 0.6300 - val_accuracy: 0.7868 - 2s/epoch - 19ms/step
# Epoch 2/30
# 114/114 - 1s - loss: 0.5844 - accuracy: 0.8067 - val_loss: 0.5361 - val_accuracy: 0.8479 - 1s/epoch - 10ms/step
# Epoch 3/30
# 114/114 - 1s - loss: 0.4934 - accuracy: 0.8502 - val_loss: 0.4529 - val_accuracy: 0.8678 - 1s/epoch - 10ms/step
# Epoch 4/30
# 114/114 - 1s - loss: 0.4231 - accuracy: 0.8709 - val_loss: 0.3954 - val_accuracy: 0.8803 - 1s/epoch - 10ms/step
# Epoch 5/30
# 114/114 - 1s - loss: 0.3760 - accuracy: 0.8814 - val_loss: 0.3579 - val_accuracy: 0.8853 - 1s/epoch - 10ms/step
# Epoch 6/30
# 114/114 - 1s - loss: 0.3447 - accuracy: 0.8868 - val_loss: 0.3329 - val_accuracy: 0.8906 - 1s/epoch - 13ms/step
# Epoch 7/30
# 114/114 - 2s - loss: 0.3231 - accuracy: 0.8917 - val_loss: 0.3162 - val_accuracy: 0.8904 - 2s/epoch - 14ms/step
# Epoch 8/30
# 114/114 - 1s - loss: 0.3076 - accuracy: 0.8941 - val_loss: 0.3031 - val_accuracy: 0.8949 - 1s/epoch - 11ms/step
# Epoch 9/30
# 114/114 - 1s - loss: 0.2960 - accuracy: 0.8965 - val_loss: 0.2939 - val_accuracy: 0.8982 - 1s/epoch - 10ms/step
# Epoch 10/30
# 114/114 - 1s - loss: 0.2871 - accuracy: 0.8994 - val_loss: 0.2868 - val_accuracy: 0.8998 - 1s/epoch - 10ms/step
# Epoch 11/30
# 114/114 - 1s - loss: 0.2802 - accuracy: 0.9009 - val_loss: 0.2815 - val_accuracy: 0.8995 - 1s/epoch - 10ms/step
# Epoch 12/30
# 114/114 - 1s - loss: 0.2748 - accuracy: 0.9020 - val_loss: 0.2776 - val_accuracy: 0.9014 - 1s/epoch - 10ms/step
# Epoch 13/30
# 114/114 - 1s - loss: 0.2704 - accuracy: 0.9029 - val_loss: 0.2744 - val_accuracy: 0.9006 - 1s/epoch - 10ms/step
# Epoch 14/30
# 114/114 - 1s - loss: 0.2670 - accuracy: 0.9036 - val_loss: 0.2719 - val_accuracy: 0.9024 - 905ms/epoch - 8ms/step
# Epoch 15/30
# 114/114 - 1s - loss: 0.2639 - accuracy: 0.9046 - val_loss: 0.2699 - val_accuracy: 0.9030 - 1s/epoch - 9ms/step
# Epoch 16/30
# 114/114 - 1s - loss: 0.2615 - accuracy: 0.9057 - val_loss: 0.2684 - val_accuracy: 0.9034 - 914ms/epoch - 8ms/step
# Epoch 17/30
# 114/114 - 1s - loss: 0.2595 - accuracy: 0.9061 - val_loss: 0.2673 - val_accuracy: 0.9038 - 1s/epoch - 10ms/step
# Epoch 18/30
# 114/114 - 1s - loss: 0.2578 - accuracy: 0.9064 - val_loss: 0.2664 - val_accuracy: 0.9029 - 1s/epoch - 13ms/step
# Epoch 19/30
# 114/114 - 1s - loss: 0.2564 - accuracy: 0.9070 - val_loss: 0.2656 - val_accuracy: 0.9039 - 1s/epoch - 13ms/step
# Epoch 20/30
# 114/114 - 1s - loss: 0.2551 - accuracy: 0.9072 - val_loss: 0.2651 - val_accuracy: 0.9038 - 942ms/epoch - 8ms/step
# Epoch 21/30
# 114/114 - 1s - loss: 0.2541 - accuracy: 0.9075 - val_loss: 0.2648 - val_accuracy: 0.9041 - 956ms/epoch - 8ms/step
# Epoch 22/30
# 114/114 - 1s - loss: 0.2532 - accuracy: 0.9077 - val_loss: 0.2645 - val_accuracy: 0.9042 - 932ms/epoch - 8ms/step
# Epoch 23/30
# 114/114 - 1s - loss: 0.2524 - accuracy: 0.9079 - val_loss: 0.2642 - val_accuracy: 0.9042 - 1s/epoch - 10ms/step
# Epoch 24/30
# 114/114 - 2s - loss: 0.2517 - accuracy: 0.9080 - val_loss: 0.2642 - val_accuracy: 0.9041 - 2s/epoch - 14ms/step
# Epoch 25/30
# 114/114 - 2s - loss: 0.2512 - accuracy: 0.9082 - val_loss: 0.2640 - val_accuracy: 0.9043 - 2s/epoch - 15ms/step
# Epoch 26/30
# 114/114 - 2s - loss: 0.2506 - accuracy: 0.9085 - val_loss: 0.2641 - val_accuracy: 0.9039 - 2s/epoch - 14ms/step
# Epoch 27/30
# 114/114 - 1s - loss: 0.2502 - accuracy: 0.9081 - val_loss: 0.2640 - val_accuracy: 0.9040 - 1s/epoch - 10ms/step
# Epoch 28/30
# 114/114 - 2s - loss: 0.2497 - accuracy: 0.9085 - val_loss: 0.2642 - val_accuracy: 0.9041 - 2s/epoch - 14ms/step
# Epoch 29/30
# 114/114 - 2s - loss: 0.2494 - accuracy: 0.9088 - val_loss: 0.2642 - val_accuracy: 0.9041 - 2s/epoch - 14ms/step
# Epoch 30/30
# 114/114 - 1s - loss: 0.2490 - accuracy: 0.9090 - val_loss: 0.2645 - val_accuracy: 0.9022 - 1s/epoch - 11ms/step

# %%
learning_curve(history1)

# %%
# model hyperparameters
embedding_dim = 16
num_epochs = 15
batch_size = 1000

# LSTM setup
model2 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8)),
    tf.keras.layers.Dense(8, activation='tanh'),
    tf.keras.layers.Dense(2, activation='softmax')
])
model2.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

model2.summary()

history2 = model2.fit(train_padded, tf.one_hot(train_labels,2), batch_size=batch_size, epochs=num_epochs, validation_data=(test_padded, tf.one_hot(test_labels,2)), verbose=2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 50, 16)            40000
#
#  bidirectional (Bidirection  (None, 16)                1600
#  al)
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 2)                 18
#
# =================================================================
# Total params: 41754 (163.10 KB)
# Trainable params: 41754 (163.10 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/15
# 114/114 - 19s - loss: 0.5378 - accuracy: 0.7522 - val_loss: 0.2811 - val_accuracy: 0.8899 - 19s/epoch - 165ms/step
# Epoch 2/15
# 114/114 - 13s - loss: 0.2553 - accuracy: 0.8997 - val_loss: 0.2452 - val_accuracy: 0.9030 - 13s/epoch - 110ms/step
# Epoch 3/15
# 114/114 - 13s - loss: 0.2348 - accuracy: 0.9079 - val_loss: 0.2378 - val_accuracy: 0.9059 - 13s/epoch - 117ms/step
# Epoch 4/15
# 114/114 - 13s - loss: 0.2262 - accuracy: 0.9106 - val_loss: 0.2360 - val_accuracy: 0.9056 - 13s/epoch - 116ms/step
# Epoch 5/15
# 114/114 - 13s - loss: 0.2227 - accuracy: 0.9120 - val_loss: 0.2342 - val_accuracy: 0.9059 - 13s/epoch - 118ms/step
# Epoch 6/15
# 114/114 - 14s - loss: 0.2167 - accuracy: 0.9143 - val_loss: 0.2358 - val_accuracy: 0.9054 - 14s/epoch - 118ms/step
# Epoch 7/15
# 114/114 - 13s - loss: 0.2142 - accuracy: 0.9147 - val_loss: 0.2357 - val_accuracy: 0.9060 - 13s/epoch - 118ms/step
# Epoch 8/15
# 114/114 - 12s - loss: 0.2105 - accuracy: 0.9164 - val_loss: 0.2374 - val_accuracy: 0.9046 - 12s/epoch - 109ms/step
# Epoch 9/15
# 114/114 - 14s - loss: 0.2081 - accuracy: 0.9175 - val_loss: 0.2361 - val_accuracy: 0.9060 - 14s/epoch - 120ms/step
# Epoch 10/15
# 114/114 - 13s - loss: 0.2049 - accuracy: 0.9189 - val_loss: 0.2382 - val_accuracy: 0.9062 - 13s/epoch - 117ms/step
# Epoch 11/15
# 114/114 - 13s - loss: 0.2024 - accuracy: 0.9199 - val_loss: 0.2382 - val_accuracy: 0.9054 - 13s/epoch - 110ms/step
# Epoch 12/15
# 114/114 - 15s - loss: 0.1992 - accuracy: 0.9219 - val_loss: 0.2388 - val_accuracy: 0.9054 - 15s/epoch - 129ms/step
# Epoch 13/15
# 114/114 - 13s - loss: 0.1962 - accuracy: 0.9227 - val_loss: 0.2416 - val_accuracy: 0.9061 - 13s/epoch - 111ms/step
# Epoch 14/15
# 114/114 - 14s - loss: 0.1922 - accuracy: 0.9244 - val_loss: 0.2432 - val_accuracy: 0.9061 - 14s/epoch - 126ms/step
# Epoch 15/15
# 114/114 - 15s - loss: 0.1893 - accuracy: 0.9256 - val_loss: 0.2453 - val_accuracy: 0.9042 - 15s/epoch - 132ms/step

# %%
learning_curve(history2)

# %%
# model hyperparameters
embedding_dim = 8
num_epochs = 15
batch_size = 1000

# flatten layer
model3 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(8, activation='sigmoid'),
    tf.keras.layers.Dense(2, activation='softmax')
])
model3.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

model3.summary()

history3 = model3.fit(train_padded, tf.one_hot(train_labels,2), batch_size=batch_size, epochs=num_epochs, validation_data=(test_padded, tf.one_hot(test_labels,2)), verbose=2)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 50, 8)             20000
#
#  flatten (Flatten)           (None, 400)               0
#
#  dense_3 (Dense)             (None, 8)                 3208
#
#  dense_4 (Dense)             (None, 2)                 18
#
# =================================================================
# Total params: 23226 (90.73 KB)
# Trainable params: 23226 (90.73 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/15
# 114/114 - 2s - loss: 0.6822 - accuracy: 0.6302 - val_loss: 0.5660 - val_accuracy: 0.8515 - 2s/epoch - 17ms/step
# Epoch 2/15
# 114/114 - 1s - loss: 0.4450 - accuracy: 0.8729 - val_loss: 0.3521 - val_accuracy: 0.8885 - 1s/epoch - 9ms/step
# Epoch 3/15
# 114/114 - 1s - loss: 0.3125 - accuracy: 0.8939 - val_loss: 0.2861 - val_accuracy: 0.8974 - 1s/epoch - 9ms/step
# Epoch 4/15
# 114/114 - 1s - loss: 0.2689 - accuracy: 0.9022 - val_loss: 0.2636 - val_accuracy: 0.9013 - 903ms/epoch - 8ms/step
# Epoch 5/15
# 114/114 - 1s - loss: 0.2509 - accuracy: 0.9063 - val_loss: 0.2546 - val_accuracy: 0.9023 - 891ms/epoch - 8ms/step
# Epoch 6/15
# 114/114 - 1s - loss: 0.2415 - accuracy: 0.9095 - val_loss: 0.2500 - val_accuracy: 0.9038 - 1s/epoch - 9ms/step
# Epoch 7/15
# 114/114 - 2s - loss: 0.2356 - accuracy: 0.9113 - val_loss: 0.2484 - val_accuracy: 0.9043 - 2s/epoch - 13ms/step
# Epoch 8/15
# 114/114 - 1s - loss: 0.2316 - accuracy: 0.9133 - val_loss: 0.2475 - val_accuracy: 0.9048 - 1s/epoch - 12ms/step
# Epoch 9/15
# 114/114 - 1s - loss: 0.2284 - accuracy: 0.9148 - val_loss: 0.2472 - val_accuracy: 0.9045 - 1s/epoch - 10ms/step
# Epoch 10/15
# 114/114 - 1s - loss: 0.2262 - accuracy: 0.9157 - val_loss: 0.2474 - val_accuracy: 0.9044 - 1s/epoch - 9ms/step
# Epoch 11/15
# 114/114 - 1s - loss: 0.2236 - accuracy: 0.9168 - val_loss: 0.2477 - val_accuracy: 0.9044 - 888ms/epoch - 8ms/step
# Epoch 12/15
# 114/114 - 1s - loss: 0.2213 - accuracy: 0.9177 - val_loss: 0.2477 - val_accuracy: 0.9043 - 1s/epoch - 9ms/step
# Epoch 13/15
# 114/114 - 1s - loss: 0.2189 - accuracy: 0.9188 - val_loss: 0.2481 - val_accuracy: 0.9044 - 889ms/epoch - 8ms/step
# Epoch 14/15
# 114/114 - 1s - loss: 0.2166 - accuracy: 0.9201 - val_loss: 0.2486 - val_accuracy: 0.9046 - 925ms/epoch - 8ms/step
# Epoch 15/15
# 114/114 - 1s - loss: 0.2142 - accuracy: 0.9210 - val_loss: 0.2492 - val_accuracy: 0.9044 - 1s/epoch - 9ms/step

# %%
learning_curve(history3)

# %%
# model hyperparameters
embedding_dim = 16
num_epochs = 15
batch_size = 1000

# convolution
model4 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(2, activation='softmax')
])
model4.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

model4.summary()

history4 = model4.fit(train_padded, tf.one_hot(train_labels,2), batch_size=batch_size, epochs=num_epochs, validation_data=(test_padded, tf.one_hot(test_labels,2)), verbose=2)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 50, 16)            40000
#
#  conv1d (Conv1D)             (None, 46, 128)           10368
#
#  global_max_pooling1d (Glob  (None, 128)               0
#  alMaxPooling1D)
#
#  dense_5 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 50626 (197.76 KB)
# Trainable params: 50626 (197.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/15
# 114/114 - 17s - loss: 0.4744 - accuracy: 0.7907 - val_loss: 0.2861 - val_accuracy: 0.8812 - 17s/epoch - 153ms/step
# Epoch 2/15
# 114/114 - 16s - loss: 0.2679 - accuracy: 0.8919 - val_loss: 0.2588 - val_accuracy: 0.8950 - 16s/epoch - 144ms/step
# Epoch 3/15
# 114/114 - 16s - loss: 0.2443 - accuracy: 0.9039 - val_loss: 0.2491 - val_accuracy: 0.8996 - 16s/epoch - 142ms/step
# Epoch 4/15
# 114/114 - 16s - loss: 0.2297 - accuracy: 0.9100 - val_loss: 0.2434 - val_accuracy: 0.9021 - 16s/epoch - 139ms/step
# Epoch 5/15
# 114/114 - 16s - loss: 0.2189 - accuracy: 0.9150 - val_loss: 0.2381 - val_accuracy: 0.9044 - 16s/epoch - 138ms/step
# Epoch 6/15
# 114/114 - 16s - loss: 0.2088 - accuracy: 0.9203 - val_loss: 0.2352 - val_accuracy: 0.9067 - 16s/epoch - 139ms/step
# Epoch 7/15
# 114/114 - 16s - loss: 0.2006 - accuracy: 0.9238 - val_loss: 0.2320 - val_accuracy: 0.9073 - 16s/epoch - 139ms/step
# Epoch 8/15
# 114/114 - 16s - loss: 0.1921 - accuracy: 0.9275 - val_loss: 0.2298 - val_accuracy: 0.9090 - 16s/epoch - 142ms/step
# Epoch 9/15
# 114/114 - 16s - loss: 0.1836 - accuracy: 0.9315 - val_loss: 0.2288 - val_accuracy: 0.9096 - 16s/epoch - 139ms/step
# Epoch 10/15
# 114/114 - 16s - loss: 0.1758 - accuracy: 0.9347 - val_loss: 0.2292 - val_accuracy: 0.9106 - 16s/epoch - 141ms/step
# Epoch 11/15
# 114/114 - 16s - loss: 0.1688 - accuracy: 0.9382 - val_loss: 0.2305 - val_accuracy: 0.9107 - 16s/epoch - 142ms/step
# Epoch 12/15
# 114/114 - 17s - loss: 0.1609 - accuracy: 0.9417 - val_loss: 0.2322 - val_accuracy: 0.9109 - 17s/epoch - 147ms/step
# Epoch 13/15
# 114/114 - 16s - loss: 0.1535 - accuracy: 0.9453 - val_loss: 0.2352 - val_accuracy: 0.9102 - 16s/epoch - 139ms/step
# Epoch 14/15
# 114/114 - 16s - loss: 0.1471 - accuracy: 0.9481 - val_loss: 0.2400 - val_accuracy: 0.9090 - 16s/epoch - 142ms/step
# Epoch 15/15
# 114/114 - 15s - loss: 0.1404 - accuracy: 0.9508 - val_loss: 0.2419 - val_accuracy: 0.9089 - 15s/epoch - 131ms/step

# %%
learning_curve(history4)

# %%
# model hyperparameters
embedding_dim = 16
num_epochs = 15
batch_size = 1000

# more complicated LSTM setup
model5 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16)),
    tf.keras.layers.Dense(8, activation='tanh'),
    tf.keras.layers.Dense(2, activation='softmax')
])
model5.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

model5.summary()

history5 = model5.fit(train_padded, tf.one_hot(train_labels,2), batch_size=batch_size, epochs=num_epochs, validation_data=(test_padded, tf.one_hot(test_labels,2)), verbose=2)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 50, 16)            40000
#
#  bidirectional_1 (Bidirecti  (None, 50, 64)            12544
#  onal)
#
#  bidirectional_2 (Bidirecti  (None, 32)                10368
#  onal)
#
#  dense_6 (Dense)             (None, 8)                 264
#
#  dense_7 (Dense)             (None, 2)                 18
#
# =================================================================
# Total params: 63194 (246.85 KB)
# Trainable params: 63194 (246.85 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/15
# 114/114 - 94s - loss: 0.4044 - accuracy: 0.8098 - val_loss: 0.2514 - val_accuracy: 0.9005 - 94s/epoch - 821ms/step
# Epoch 2/15
# 114/114 - 83s - loss: 0.2407 - accuracy: 0.9050 - val_loss: 0.2670 - val_accuracy: 0.8894 - 83s/epoch - 732ms/step
# Epoch 3/15
# 114/114 - 83s - loss: 0.2338 - accuracy: 0.9071 - val_loss: 0.2378 - val_accuracy: 0.9047 - 83s/epoch - 724ms/step
# Epoch 4/15
# 114/114 - 85s - loss: 0.2255 - accuracy: 0.9108 - val_loss: 0.2379 - val_accuracy: 0.9049 - 85s/epoch - 744ms/step
# Epoch 5/15
# 114/114 - 83s - loss: 0.2207 - accuracy: 0.9127 - val_loss: 0.2420 - val_accuracy: 0.9038 - 83s/epoch - 728ms/step
# Epoch 6/15
# 114/114 - 84s - loss: 0.2159 - accuracy: 0.9143 - val_loss: 0.2349 - val_accuracy: 0.9049 - 84s/epoch - 733ms/step
# Epoch 7/15
# 114/114 - 82s - loss: 0.2107 - accuracy: 0.9169 - val_loss: 0.2409 - val_accuracy: 0.9045 - 82s/epoch - 721ms/step
# Epoch 8/15
# 114/114 - 83s - loss: 0.2066 - accuracy: 0.9184 - val_loss: 0.2457 - val_accuracy: 0.9012 - 83s/epoch - 725ms/step
# Epoch 9/15
# 114/114 - 83s - loss: 0.2034 - accuracy: 0.9199 - val_loss: 0.2391 - val_accuracy: 0.9039 - 83s/epoch - 730ms/step
# Epoch 10/15
# 114/114 - 84s - loss: 0.2026 - accuracy: 0.9206 - val_loss: 0.2405 - val_accuracy: 0.9059 - 84s/epoch - 740ms/step
# Epoch 11/15
# 114/114 - 83s - loss: 0.1950 - accuracy: 0.9242 - val_loss: 0.2431 - val_accuracy: 0.9036 - 83s/epoch - 732ms/step
# Epoch 12/15
# 114/114 - 84s - loss: 0.1921 - accuracy: 0.9253 - val_loss: 0.2407 - val_accuracy: 0.9049 - 84s/epoch - 736ms/step
# Epoch 13/15
# 114/114 - 83s - loss: 0.1866 - accuracy: 0.9279 - val_loss: 0.2406 - val_accuracy: 0.9053 - 83s/epoch - 727ms/step
# Epoch 14/15
# 114/114 - 83s - loss: 0.1803 - accuracy: 0.9307 - val_loss: 0.2503 - val_accuracy: 0.9065 - 83s/epoch - 732ms/step
# Epoch 15/15
# 114/114 - 87s - loss: 0.1755 - accuracy: 0.9325 - val_loss: 0.2435 - val_accuracy: 0.9062 - 87s/epoch - 762ms/step

# %%
learning_curve(history5)

# %%
# Plot all five learning curves on the same axes.
plt.figure(figsize=(14,10))

# plt.axhline(0.5, label='Baseline', color='black')
plt.plot(history1.history['accuracy'], label='Pooling (Train)', color='orange', linestyle='dashed')
plt.plot(history1.history['val_accuracy'], label='Pooling (Test)', color='orange')
plt.plot(history2.history['accuracy'], label='LSTM (Train)', color='red', linestyle='dashed')
plt.plot(history2.history['val_accuracy'], label='LSTM (Test)', color='red')
plt.plot(history3.history['accuracy'], label='Flatten (Train)', color='green', linestyle='dashed')
plt.plot(history3.history['val_accuracy'], label='Flatten (Test)', color='green')
plt.plot(history4.history['accuracy'], label='Convolution (Train)', color='blue', linestyle='dashed')
plt.plot(history4.history['val_accuracy'], label='Convolution (Test)', color='blue')
plt.plot(history5.history['accuracy'], label='Stacked LSTM (Train)', color='purple', linestyle='dashed')
plt.plot(history5.history['val_accuracy'], label='Stacked LSTM (Test)', color='purple')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xlim(0,14)
# plt.ylim((0.5,0.8))
plt.title('Learning Curves for NLP Binary Classification')

plt.show()

# %% [markdown]
# # Confusion matrix analysis
# ---

# %%
from sklearn.metrics import confusion_matrix
import itertools

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print("Normalised confusion matrix")
  else:
    print("Confusion matrix without normalisation")

  print(cm)

  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i,j],
             horizontalalignment='center',
             color='white' if cm[i,j] > thresh else 'black')
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def confusion_matrix_complete(model, classes=['Negative', 'Positive'],
                              normalize=False, title='Confusion Matrix', cmap=plt.cm.Blues):

  model_raw_predictions = model.predict(test_padded)
  model_rounded_predictions = np.argmax(model_raw_predictions, axis=-1)

  cm = confusion_matrix(y_true = test_labels, y_pred = model_rounded_predictions)

  plot_confusion_matrix(cm=cm, classes=classes, title=title)

# %%
# set plotting style for confusion matrices
sns.reset_orig()

# %%
confusion_matrix_complete(model=model1, title='Confusion Matrix for Pooling-layer Model')
# Out:
# 1821/1821 [==============================] - 6s 3ms/step
# Confusion matrix without normalisation
# [[25965  3152]
#  [ 2549 26604]]

# %%
confusion_matrix_complete(model=model2, title='Confusion Matrix for LSTM Model')
# Out:
# 1821/1821 [==============================] - 19s 9ms/step
# Confusion matrix without normalisation
# [[26509  2608]
#  [ 2974 26179]]

# %%
confusion_matrix_complete(model=model3, title='Confusion Matrix for Flatten-layer Model')
# Out:
# 1821/1821 [==============================] - 3s 1ms/step
# Confusion matrix without normalisation
# [[26382  2735]
#  [ 2836 26317]]

# %%
confusion_matrix_complete(model=model4, title='Confusion Matrix for Convolutional-layer Model')
# Out:
# 1821/1821 [==============================] - 5s 3ms/step
# Confusion matrix without normalisation
# [[26408  2709]
#  [ 2602 26551]]

# %%
confusion_matrix_complete(model=model5, title='Confusion Matrix for Stacked LSTM Model')
# Out:
# 1821/1821 [==============================] - 36s 19ms/step
# Confusion matrix without normalisation
# [[26528  2589]
#  [ 2879 26274]]
